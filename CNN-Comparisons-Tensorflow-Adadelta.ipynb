# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten,Dense
from tensorflow.keras.datasets import mnist 
from tensorflow.keras.utils import to_categorical

# %%
(inputs,results),(testing_inputs,testing_results) = mnist.load_data()

# %%
inputs = inputs.reshape(inputs.shape[0],1,28,28)
testing_inputs = testing_inputs.reshape(testing_inputs.shape[0],1,28,28)
inputs = inputs.astype('float32')
testing_inputs = testing_inputs.astype('float32')
inputs = inputs/255
testing_inputs = testing_inputs/255

results = to_categorical(results,10)
testing_results = to_categorical(testing_results,10)

# %%
results.shape
# Out:
# (60000, 10)

# %%
model = Sequential()

model.add(Conv2D(8,kernel_size=(3,3), padding='same', input_shape = (1,28,28),activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2),padding='same'))
model.add(Conv2D(64,kernel_size=(3,3),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),padding='same'))
model.add(Conv2D(128,kernel_size=(3,3),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),padding='same'))
model.add(Conv2D(10,kernel_size=(3,3),padding='same',activation='softmax'))
model.add(MaxPool2D(pool_size=(4,4),padding='same'))
model.add(Flatten())


opt = tensorflow.keras.optimizers.Adadelta(lr=.01)
model.compile(loss = 'categorical_crossentropy',optimizer =opt,metrics=['accuracy'] )
model.fit(inputs,
          results,
          epochs = 100,
          batch_size = 60000,
          verbose = 2, 
          steps_per_epoch =1,
          validation_data=(testing_inputs,testing_results),
          validation_steps = 1)
# Out:
# Epoch 1/100
# 1/1 - 1s - loss: 2.3031 - accuracy: 0.1179 - val_loss: 2.3030 - val_accuracy: 0.1192
# Epoch 2/100
# 1/1 - 1s - loss: 2.3031 - accuracy: 0.1181 - val_loss: 2.3030 - val_accuracy: 0.1193
# Epoch 3/100
# 1/1 - 1s - loss: 2.3031 - accuracy: 0.1183 - val_loss: 2.3030 - val_accuracy: 0.1195
# Epoch 4/100
# 1/1 - 1s - loss: 2.3030 - accuracy: 0.1184 - val_loss: 2.3030 - val_accuracy: 0.1196
# Epoch 5/100
# 1/1 - 1s - loss: 2.3030 - accuracy: 0.1185 - val_loss: 2.3030 - val_accuracy: 0.1198
# Epoch 6/100
# 1/1 - 1s - loss: 2.3030 - accuracy: 0.1187 - val_loss: 2.3030 - val_accuracy: 0.1198
# Epoch 7/100
# 1/1 - 1s - loss: 2.3030 - accuracy: 0.1190 - val_loss: 2.3029 - val_accuracy: 0.1198
# Epoch 8/100
# 1/1 - 1s - loss: 2.3030 - accuracy: 0.1191 - val_loss: 2.3029 - val_accuracy: 0.1203
# Epoch 9/100
# 1/1 - 1s - loss: 2.3030 - accuracy: 0.1192 - val_loss: 2.3029 - val_accuracy: 0.1204
# Epoch 10/100
# ...
