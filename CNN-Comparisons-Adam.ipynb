# %%
import tensorflow
from tensorflow.keras.datasets import mnist 
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten 
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical


(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(x_train.shape[0],1,28,28)
x_test = x_test.reshape(x_test.shape[0],1,28,28)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
model = Sequential()

model.add(Conv2D(8,kernel_size = 3 , padding = 'same', activation = 'relu',input_shape=(1,28,28)))
model.add(MaxPool2D(pool_size = (2,2),padding='same'))
model.add(Conv2D(64,kernel_size = 3 , padding = 'same', activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2),padding='same'))
model.add(Conv2D(128,kernel_size = 3 , padding = 'same', activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2),padding='same'))
model.add(Conv2D(10,kernel_size = 3 , padding = 'same', activation = 'softmax'))
model.add(MaxPool2D(pool_size = (4,4),padding='same'))
model.add(Flatten())

model.compile(loss = 'categorical_crossentropy',optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy'])

# %%
model.fit(x_train,y_train,batch_size=60000,epochs = 150,steps_per_epoch = 1,validation_data=(x_test,y_test),verbose = 2,
         validation_steps=1)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/150
# 60000/60000 - 66s - loss: 2.3027 - accuracy: 0.0822 - val_loss: 2.2999 - val_accuracy: 0.1456
# Epoch 2/150
# 60000/60000 - 62s - loss: 2.2998 - accuracy: 0.1544 - val_loss: 2.2970 - val_accuracy: 0.2077
# Epoch 3/150
# 60000/60000 - 66s - loss: 2.2970 - accuracy: 0.2151 - val_loss: 2.2940 - val_accuracy: 0.2516
# Epoch 4/150
# 60000/60000 - 67s - loss: 2.2941 - accuracy: 0.2559 - val_loss: 2.2907 - val_accuracy: 0.2742
# Epoch 5/150
# 60000/60000 - 65s - loss: 2.2908 - accuracy: 0.2785 - val_loss: 2.2868 - val_accuracy: 0.2880
# Epoch 6/150
# 60000/60000 - 65s - loss: 2.2870 - accuracy: 0.2894 - val_loss: 2.2823 - val_accuracy: 0.2963
# Epoch 7/150
# 60000/60000 - 63s - loss: 2.2826 - accuracy: 0.2953 - val_loss: 2.2771 - val_accuracy: 0.2978
# Epoch 8/150
# 60000/60000 - 66s - loss: 2.2775 - accuracy: 0.2976 - val_loss: 2.2711 - val_accuracy: 0.2962
# Epoch 9/150
# 60000/60000 - 75s - loss: 2.2716 - accuracy: 0.2955 - val_loss: 2.2641 - val_accuracy: 0.2917
# Epoch 10/150
# 60000/60000 - 73s - loss: 2.2649 - accuracy: 0.2920 - val_loss: 2.2562 - val_accuracy: 0.2905
# Epoch 11/150
# 60000/60000 - 78s - loss: 2.2571 - accuracy: 0.2900 - val_loss: 2.2472 - val_accuracy: 0.2911
# Epoch 12/150
# 60000/60000 - 68s - loss: 2.2483 - accuracy: 0.2907 - val_loss: 2.2370 - val_accuracy: 0.2978
# Epoch 13/150
# 60000/60000 - 65s - loss: 2.2384 - accuracy: 0.2950 - val_loss: 2.2254 - val_accuracy: 0.3093
# Epoch 14/150
# 60000/60000 - 64s - loss: 2.2271 - accuracy: 0.3032 - val_loss: 2.2124 - val_accuracy: 0.3211
# Epoch 15/150
# 60000/60000 - 62s - loss: 2.2144 - accuracy: 0.3167 - val_loss: 2.1980 - val_accuracy: 0.3345
# Epoch 16/150
# 60000/60000 - 65s - loss: 2.2004 - accuracy: 0.3318 - val_loss: 2.1820 - val_accuracy: 0.3522
# Epoch 17/150
# 60000/60000 - 65s - loss: 2.1849 - accuracy: 0.3510 - val_loss: 2.1645 - val_accuracy: 0.3754
# Epoch 18/150
# 60000/60000 - 64s - loss: 2.1678 - accuracy: 0.3713 - val_loss: 2.1452 - val_accuracy: 0.4012
# Epoch 19/150
# 60000/60000 - 67s - loss: 2.1490 - accuracy: 0.3949 - val_loss: 2.1240 - val_accuracy: 0.4229
# Epoch 20/150
# 60000/60000 - 61s - loss: 2.1285 - accuracy: 0.4167 - val_loss: 2.1009 - val_accuracy: 0.4475
# Epoch 21/150
# 60000/60000 - 66s - loss: 2.1061 - accuracy: 0.4387 - val_loss: 2.0758 - val_accuracy: 0.4670
# Epoch 22/150
# 60000/60000 - 57s - loss: 2.0817 - accuracy: 0.4606 - val_loss: 2.0488 - val_accuracy: 0.4887
# Epoch 23/150
# 60000/60000 - 57s - loss: 2.0554 - accuracy: 0.4816 - val_loss: 2.0198 - val_accuracy: 0.5099
# Epoch 24/150
# 60000/60000 - 51s - loss: 2.0271 - accuracy: 0.5017 - val_loss: 1.9887 - val_accuracy: 0.5345
# Epoch 25/150
# 60000/60000 - 49s - loss: 1.9970 - accuracy: 0.5231 - val_loss: 1.9557 - val_accuracy: 0.5557
# Epoch 26/150
# 60000/60000 - 55s - loss: 1.9648 - accuracy: 0.5444 - val_loss: 1.9208 - val_accuracy: 0.5776
# Epoch 27/150
# 60000/60000 - 59s - loss: 1.9308 - accuracy: 0.5653 - val_loss: 1.8841 - val_accuracy: 0.5998
# Epoch 28/150
# 60000/60000 - 59s - loss: 1.8950 - accuracy: 0.5826 - val_loss: 1.8458 - val_accuracy: 0.6181
# Epoch 29/150
# 60000/60000 - 58s - loss: 1.8577 - accuracy: 0.6010 - val_loss: 1.8063 - val_accuracy: 0.6349
# Epoch 30/150
# 60000/60000 - 57s - loss: 1.8191 - accuracy: 0.6213 - val_loss: 1.7658 - val_accuracy: 0.6531
# Epoch 31/150
# 60000/60000 - 59s - loss: 1.7795 - accuracy: 0.6420 - val_loss: 1.7247 - val_accuracy: 0.6713
# Epoch 32/150
# 60000/60000 - 59s - loss: 1.7392 - accuracy: 0.6593 - val_loss: 1.6836 - val_accuracy: 0.6866
# Epoch 33/150
# 60000/60000 - 57s - loss: 1.6988 - accuracy: 0.6726 - val_loss: 1.6428 - val_accuracy: 0.6996
# Epoch 34/150
# 60000/60000 - 57s - loss: 1.6587 - accuracy: 0.6852 - val_loss: 1.6030 - val_accuracy: 0.7080
# Epoch 35/150
# 60000/60000 - 55s - loss: 1.6195 - accuracy: 0.6916 - val_loss: 1.5647 - val_accuracy: 0.7125
# Epoch 36/150
# 60000/60000 - 57s - loss: 1.5816 - accuracy: 0.6976 - val_loss: 1.5283 - val_accuracy: 0.7143
# Epoch 37/150
# 60000/60000 - 57s - loss: 1.5455 - accuracy: 0.7002 - val_loss: 1.4940 - val_accuracy: 0.7172
# Epoch 38/150
# 60000/60000 - 57s - loss: 1.5112 - accuracy: 0.7025 - val_loss: 1.4619 - val_accuracy: 0.7207
# Epoch 39/150
# 60000/60000 - 56s - loss: 1.4792 - accuracy: 0.7049 - val_loss: 1.4319 - val_accuracy: 0.7233
# Epoch 40/150
# 60000/60000 - 55s - loss: 1.4493 - accuracy: 0.7089 - val_loss: 1.4040 - val_accuracy: 0.7260
# Epoch 41/150
# 60000/60000 - 55s - loss: 1.4214 - accuracy: 0.7127 - val_loss: 1.3779 - val_accuracy: 0.7283
# Epoch 42/150
# 60000/60000 - 57s - loss: 1.3954 - accuracy: 0.7150 - val_loss: 1.3534 - val_accuracy: 0.7314
# Epoch 43/150
# 60000/60000 - 58s - loss: 1.3712 - accuracy: 0.7182 - val_loss: 1.3306 - val_accuracy: 0.7350
# Epoch 44/150
# 60000/60000 - 55s - loss: 1.3486 - accuracy: 0.7221 - val_loss: 1.3089 - val_accuracy: 0.7376
# Epoch 45/150
# 60000/60000 - 55s - loss: 1.3272 - accuracy: 0.7258 - val_loss: 1.2884 - val_accuracy: 0.7415
# Epoch 46/150
# 60000/60000 - 56s - loss: 1.3069 - accuracy: 0.7302 - val_loss: 1.2686 - val_accuracy: 0.7488
# Epoch 47/150
# 60000/60000 - 56s - loss: 1.2874 - accuracy: 0.7363 - val_loss: 1.2498 - val_accuracy: 0.7571
# Epoch 48/150
# 60000/60000 - 56s - loss: 1.2687 - accuracy: 0.7416 - val_loss: 1.2319 - val_accuracy: 0.7626
# Epoch 49/150
# 60000/60000 - 56s - loss: 1.2512 - accuracy: 0.7457 - val_loss: 1.2161 - val_accuracy: 0.7661
# Epoch 50/150
# 60000/60000 - 56s - loss: 1.2352 - accuracy: 0.7505 - val_loss: 1.2013 - val_accuracy: 0.7733
# Epoch 51/150
# 60000/60000 - 53s - loss: 1.2202 - accuracy: 0.7564 - val_loss: 1.1875 - val_accuracy: 0.7752
# Epoch 52/150
# 60000/60000 - 50s - loss: 1.2053 - accuracy: 0.7621 - val_loss: 1.1719 - val_accuracy: 0.7802
# Epoch 53/150
# 60000/60000 - 52s - loss: 1.1898 - accuracy: 0.7654 - val_loss: 1.1573 - val_accuracy: 0.7819
# Epoch 54/150
# 60000/60000 - 49s - loss: 1.1748 - accuracy: 0.7695 - val_loss: 1.1440 - val_accuracy: 0.7839
# Epoch 55/150
# 60000/60000 - 47s - loss: 1.1615 - accuracy: 0.7720 - val_loss: 1.1306 - val_accuracy: 0.7882
# Epoch 56/150
# 60000/60000 - 48s - loss: 1.1485 - accuracy: 0.7740 - val_loss: 1.1173 - val_accuracy: 0.7891
# Epoch 57/150
# 60000/60000 - 48s - loss: 1.1346 - accuracy: 0.7790 - val_loss: 1.1042 - val_accuracy: 0.7902
# Epoch 58/150
# 60000/60000 - 49s - loss: 1.1210 - accuracy: 0.7808 - val_loss: 1.0918 - val_accuracy: 0.7953
# Epoch 59/150
# 60000/60000 - 51s - loss: 1.1082 - accuracy: 0.7843 - val_loss: 1.0796 - val_accuracy: 0.7989
# Epoch 60/150
# 60000/60000 - 49s - loss: 1.0954 - accuracy: 0.7891 - val_loss: 1.0661 - val_accuracy: 0.8043
# Epoch 61/150
# 60000/60000 - 49s - loss: 1.0822 - accuracy: 0.7949 - val_loss: 1.0535 - val_accuracy: 0.8020
# Epoch 62/150
# 60000/60000 - 49s - loss: 1.0698 - accuracy: 0.7949 - val_loss: 1.0420 - val_accuracy: 0.8029
# Epoch 63/150
# 60000/60000 - 49s - loss: 1.0584 - accuracy: 0.7971 - val_loss: 1.0301 - val_accuracy: 0.8087
# Epoch 64/150
# 60000/60000 - 49s - loss: 1.0472 - accuracy: 0.8012 - val_loss: 1.0193 - val_accuracy: 0.8076
# Epoch 65/150
# 60000/60000 - 54s - loss: 1.0362 - accuracy: 0.8017 - val_loss: 1.0093 - val_accuracy: 0.8097
# Epoch 66/150
# 60000/60000 - 57s - loss: 1.0260 - accuracy: 0.8046 - val_loss: 1.0001 - val_accuracy: 0.8133
# Epoch 67/150
# 60000/60000 - 58s - loss: 1.0167 - accuracy: 0.8073 - val_loss: 0.9916 - val_accuracy: 0.8144
# Epoch 68/150
# 60000/60000 - 57s - loss: 1.0079 - accuracy: 0.8084 - val_loss: 0.9823 - val_accuracy: 0.8182
# Epoch 69/150
# 60000/60000 - 54s - loss: 0.9991 - accuracy: 0.8114 - val_loss: 0.9737 - val_accuracy: 0.8165
# Epoch 70/150
# 60000/60000 - 56s - loss: 0.9906 - accuracy: 0.8099 - val_loss: 0.9651 - val_accuracy: 0.8219
# Epoch 71/150
# 60000/60000 - 56s - loss: 0.9826 - accuracy: 0.8122 - val_loss: 0.9569 - val_accuracy: 0.8237
# Epoch 72/150
# 60000/60000 - 54s - loss: 0.9748 - accuracy: 0.8138 - val_loss: 0.9494 - val_accuracy: 0.8210
# Epoch 73/150
# 60000/60000 - 54s - loss: 0.9671 - accuracy: 0.8122 - val_loss: 0.9413 - val_accuracy: 0.8275
# Epoch 74/150
# 60000/60000 - 55s - loss: 0.9593 - accuracy: 0.8175 - val_loss: 0.9336 - val_accuracy: 0.8262
# Epoch 75/150
# 60000/60000 - 56s - loss: 0.9516 - accuracy: 0.8166 - val_loss: 0.9260 - val_accuracy: 0.8257
# Epoch 76/150
# 60000/60000 - 59s - loss: 0.9442 - accuracy: 0.8169 - val_loss: 0.9184 - val_accuracy: 0.8277
# Epoch 77/150
# 60000/60000 - 57s - loss: 0.9369 - accuracy: 0.8181 - val_loss: 0.9112 - val_accuracy: 0.8265
# Epoch 78/150
# 60000/60000 - 56s - loss: 0.9297 - accuracy: 0.8156 - val_loss: 0.9036 - val_accuracy: 0.8305
# Epoch 79/150
# 60000/60000 - 56s - loss: 0.9223 - accuracy: 0.8200 - val_loss: 0.8965 - val_accuracy: 0.8317
# Epoch 80/150
# 60000/60000 - 56s - loss: 0.9150 - accuracy: 0.8205 - val_loss: 0.8896 - val_accuracy: 0.8328
# Epoch 81/150
# 60000/60000 - 57s - loss: 0.9077 - accuracy: 0.8211 - val_loss: 0.8822 - val_accuracy: 0.8340
# Epoch 82/150
# 60000/60000 - 57s - loss: 0.9005 - accuracy: 0.8230 - val_loss: 0.8754 - val_accuracy: 0.8324
# Epoch 83/150
# 60000/60000 - 56s - loss: 0.8933 - accuracy: 0.8200 - val_loss: 0.8684 - val_accuracy: 0.8342
# Epoch 84/150
# 60000/60000 - 54s - loss: 0.8860 - accuracy: 0.8240 - val_loss: 0.8616 - val_accuracy: 0.8342
# Epoch 85/150
# 60000/60000 - 49s - loss: 0.8790 - accuracy: 0.8235 - val_loss: 0.8553 - val_accuracy: 0.8329
# Epoch 86/150
# 60000/60000 - 49s - loss: 0.8721 - accuracy: 0.8227 - val_loss: 0.8487 - val_accuracy: 0.8343
# Epoch 87/150
# 60000/60000 - 49s - loss: 0.8653 - accuracy: 0.8248 - val_loss: 0.8430 - val_accuracy: 0.8333
# Epoch 88/150
# 60000/60000 - 49s - loss: 0.8586 - accuracy: 0.8237 - val_loss: 0.8366 - val_accuracy: 0.8344
# Epoch 89/150
# 60000/60000 - 46s - loss: 0.8519 - accuracy: 0.8257 - val_loss: 0.8308 - val_accuracy: 0.8355
# Epoch 90/150
# 60000/60000 - 47s - loss: 0.8455 - accuracy: 0.8267 - val_loss: 0.8247 - val_accuracy: 0.8324
# Epoch 91/150
# 60000/60000 - 48s - loss: 0.8392 - accuracy: 0.8257 - val_loss: 0.8194 - val_accuracy: 0.8397
# Epoch 92/150
# 60000/60000 - 48s - loss: 0.8330 - accuracy: 0.8296 - val_loss: 0.8136 - val_accuracy: 0.8330
# Epoch 93/150
# 60000/60000 - 49s - loss: 0.8269 - accuracy: 0.8269 - val_loss: 0.8086 - val_accuracy: 0.8372
# Epoch 94/150
# 60000/60000 - 49s - loss: 0.8211 - accuracy: 0.8287 - val_loss: 0.8032 - val_accuracy: 0.8364
# Epoch 95/150
# 60000/60000 - 48s - loss: 0.8154 - accuracy: 0.8305 - val_loss: 0.7987 - val_accuracy: 0.8357
# Epoch 96/150
# 60000/60000 - 47s - loss: 0.8100 - accuracy: 0.8281 - val_loss: 0.7933 - val_accuracy: 0.8380
# Epoch 97/150
# 60000/60000 - 52s - loss: 0.8050 - accuracy: 0.8311 - val_loss: 0.7896 - val_accuracy: 0.8361
# Epoch 98/150
# 60000/60000 - 56s - loss: 0.8000 - accuracy: 0.8273 - val_loss: 0.7841 - val_accuracy: 0.8369
# Epoch 99/150
# 60000/60000 - 59s - loss: 0.7951 - accuracy: 0.8306 - val_loss: 0.7803 - val_accuracy: 0.8412
# Epoch 100/150
# 60000/60000 - 58s - loss: 0.7898 - accuracy: 0.8318 - val_loss: 0.7747 - val_accuracy: 0.8356
# Epoch 101/150
# 60000/60000 - 58s - loss: 0.7844 - accuracy: 0.8299 - val_loss: 0.7702 - val_accuracy: 0.8418
# Epoch 102/150
# 60000/60000 - 57s - loss: 0.7796 - accuracy: 0.8349 - val_loss: 0.7667 - val_accuracy: 0.8383
# Epoch 103/150
# 60000/60000 - 55s - loss: 0.7753 - accuracy: 0.8321 - val_loss: 0.7618 - val_accuracy: 0.8399
# Epoch 104/150
# 60000/60000 - 55s - loss: 0.7707 - accuracy: 0.8334 - val_loss: 0.7580 - val_accuracy: 0.8439
# Epoch 105/150
# 60000/60000 - 56s - loss: 0.7660 - accuracy: 0.8365 - val_loss: 0.7540 - val_accuracy: 0.8380
# Epoch 106/150
# 60000/60000 - 57s - loss: 0.7616 - accuracy: 0.8345 - val_loss: 0.7499 - val_accuracy: 0.8434
# Epoch 107/150
# 60000/60000 - 57s - loss: 0.7575 - accuracy: 0.8381 - val_loss: 0.7464 - val_accuracy: 0.8434
# Epoch 108/150
# 60000/60000 - 58s - loss: 0.7533 - accuracy: 0.8376 - val_loss: 0.7420 - val_accuracy: 0.8412
# Epoch 109/150
# 60000/60000 - 58s - loss: 0.7490 - accuracy: 0.8368 - val_loss: 0.7382 - val_accuracy: 0.8451
# Epoch 110/150
# 60000/60000 - 58s - loss: 0.7445 - accuracy: 0.8400 - val_loss: 0.7338 - val_accuracy: 0.8438
# Epoch 111/150
# 60000/60000 - 57s - loss: 0.7398 - accuracy: 0.8391 - val_loss: 0.7281 - val_accuracy: 0.8446
# Epoch 112/150
# 60000/60000 - 57s - loss: 0.7340 - accuracy: 0.8407 - val_loss: 0.7219 - val_accuracy: 0.8452
# Epoch 113/150
# 60000/60000 - 57s - loss: 0.7274 - accuracy: 0.8409 - val_loss: 0.7157 - val_accuracy: 0.8459
# Epoch 114/150
# 60000/60000 - 57s - loss: 0.7213 - accuracy: 0.8407 - val_loss: 0.7151 - val_accuracy: 0.8440
# Epoch 115/150
# 60000/60000 - 58s - loss: 0.7200 - accuracy: 0.8401 - val_loss: 0.7112 - val_accuracy: 0.8457
# Epoch 116/150
# 60000/60000 - 57s - loss: 0.7166 - accuracy: 0.8432 - val_loss: 0.7063 - val_accuracy: 0.8456
# Epoch 117/150
# 60000/60000 - 56s - loss: 0.7111 - accuracy: 0.8409 - val_loss: 0.7019 - val_accuracy: 0.8468
# Epoch 118/150
# 60000/60000 - 55s - loss: 0.7079 - accuracy: 0.8426 - val_loss: 0.6996 - val_accuracy: 0.8431
# Epoch 119/150
# 60000/60000 - 55s - loss: 0.7050 - accuracy: 0.8395 - val_loss: 0.6962 - val_accuracy: 0.8526
# Epoch 120/150
# 60000/60000 - 58s - loss: 0.7009 - accuracy: 0.8487 - val_loss: 0.6922 - val_accuracy: 0.8564
# Epoch 121/150
# 60000/60000 - 57s - loss: 0.6968 - accuracy: 0.8512 - val_loss: 0.6902 - val_accuracy: 0.8487
# Epoch 122/150
# 60000/60000 - 58s - loss: 0.6941 - accuracy: 0.8436 - val_loss: 0.6871 - val_accuracy: 0.8553
# Epoch 123/150
# 60000/60000 - 56s - loss: 0.6914 - accuracy: 0.8504 - val_loss: 0.6841 - val_accuracy: 0.8552
# Epoch 124/150
# 60000/60000 - 56s - loss: 0.6875 - accuracy: 0.8502 - val_loss: 0.6802 - val_accuracy: 0.8546
# Epoch 125/150
# 60000/60000 - 57s - loss: 0.6835 - accuracy: 0.8502 - val_loss: 0.6764 - val_accuracy: 0.8516
# Epoch 126/150
# 60000/60000 - 60s - loss: 0.6803 - accuracy: 0.8479 - val_loss: 0.6734 - val_accuracy: 0.8448
# Epoch 127/150
# 60000/60000 - 58s - loss: 0.6773 - accuracy: 0.8409 - val_loss: 0.6697 - val_accuracy: 0.8507
# Epoch 128/150
# 60000/60000 - 57s - loss: 0.6734 - accuracy: 0.8468 - val_loss: 0.6656 - val_accuracy: 0.8524
# Epoch 129/150
# 60000/60000 - 56s - loss: 0.6692 - accuracy: 0.8503 - val_loss: 0.6615 - val_accuracy: 0.8501
# Epoch 130/150
# 60000/60000 - 56s - loss: 0.6649 - accuracy: 0.8467 - val_loss: 0.6548 - val_accuracy: 0.8528
# Epoch 131/150
# 60000/60000 - 57s - loss: 0.6590 - accuracy: 0.8514 - val_loss: 0.6485 - val_accuracy: 0.8544
# Epoch 132/150
# 60000/60000 - 57s - loss: 0.6520 - accuracy: 0.8513 - val_loss: 0.6408 - val_accuracy: 0.8528
# Epoch 133/150
# 60000/60000 - 57s - loss: 0.6453 - accuracy: 0.8487 - val_loss: 0.6362 - val_accuracy: 0.8468
# Epoch 134/150
# 60000/60000 - 56s - loss: 0.6400 - accuracy: 0.8438 - val_loss: 0.6316 - val_accuracy: 0.8455
# Epoch 135/150
# 60000/60000 - 56s - loss: 0.6359 - accuracy: 0.8436 - val_loss: 0.6289 - val_accuracy: 0.8481
# Epoch 136/150
# 60000/60000 - 55s - loss: 0.6323 - accuracy: 0.8453 - val_loss: 0.6238 - val_accuracy: 0.8446
# Epoch 137/150
# 60000/60000 - 55s - loss: 0.6284 - accuracy: 0.8431 - val_loss: 0.6193 - val_accuracy: 0.8401
# Epoch 138/150
# 60000/60000 - 55s - loss: 0.6242 - accuracy: 0.8396 - val_loss: 0.6153 - val_accuracy: 0.8401
# Epoch 139/150
# 60000/60000 - 54s - loss: 0.6200 - accuracy: 0.8379 - val_loss: 0.6115 - val_accuracy: 0.8408
# Epoch 140/150
# 60000/60000 - 57s - loss: 0.6163 - accuracy: 0.8401 - val_loss: 0.6079 - val_accuracy: 0.8399
# Epoch 141/150
# 60000/60000 - 58s - loss: 0.6124 - accuracy: 0.8397 - val_loss: 0.6039 - val_accuracy: 0.8381
# Epoch 142/150
# 60000/60000 - 58s - loss: 0.6083 - accuracy: 0.8375 - val_loss: 0.6002 - val_accuracy: 0.8438
# Epoch 143/150
# 60000/60000 - 57s - loss: 0.6042 - accuracy: 0.8425 - val_loss: 0.5969 - val_accuracy: 0.8441
# Epoch 144/150
# 60000/60000 - 57s - loss: 0.6007 - accuracy: 0.8424 - val_loss: 0.5935 - val_accuracy: 0.8430
# Epoch 145/150
# 60000/60000 - 55s - loss: 0.5974 - accuracy: 0.8423 - val_loss: 0.5908 - val_accuracy: 0.8430
# Epoch 146/150
# 60000/60000 - 55s - loss: 0.5944 - accuracy: 0.8419 - val_loss: 0.5875 - val_accuracy: 0.8444
# Epoch 147/150
# 60000/60000 - 57s - loss: 0.5915 - accuracy: 0.8438 - val_loss: 0.5848 - val_accuracy: 0.8417
# Epoch 148/150
# 60000/60000 - 56s - loss: 0.5887 - accuracy: 0.8425 - val_loss: 0.5813 - val_accuracy: 0.8462
# Epoch 149/150
# 60000/60000 - 55s - loss: 0.5857 - accuracy: 0.8457 - val_loss: 0.5790 - val_accuracy: 0.8347
# Epoch 150/150
# 60000/60000 - 54s - loss: 0.5829 - accuracy: 0.8370 - val_loss: 0.5759 - val_accuracy: 0.8473

# %%
model.save('./model.h5')

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (7.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (5.0.7)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (4.3.3)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (7.15.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: ipython-genutils in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: jupyter-core in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.0.3)
# Requirement already satisfied: six in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets) (1.15.0)
# Requirement already satisfied: decorator in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.17.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (3.0.5)
# Requirement already satisfied: pygments in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.6.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.0)
# Requirement already satisfied: backcall in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (47.3.1.post20200622)
# Requirement already satisfied: jupyter-client in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.3)
# Requirement already satisfied: tornado>=4.2 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.16.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.6.1)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (19.3.0)
# Requirement already satisfied: Send2Trash in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (19.0.1)
# Requirement already satisfied: terminado>=0.8.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.3)
# Requirement already satisfied: nbconvert in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (5.6.1)
# Requirement already satisfied: prometheus-client in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.0)
# Requirement already satisfied: jinja2 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.4)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.6.0)
# Requirement already satisfied: python-dateutil>=2.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: zipp>=0.5 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.1.0)
# Requirement already satisfied: testpath in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied: defusedxml in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: bleach in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: webencodings in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge nodejs
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /anaconda3/envs/tensorflow
#
#   added / updated specs:
#     - nodejs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.12.5  |       h033912b_0         138 KB  conda-forge
#     certifi-2020.12.5          |   py37hf985489_0         143 KB  conda-forge
#     nodejs-12.4.0              |       h6de7cb9_0        16.8 MB  conda-forge
#     openssl-1.1.1i             |       h35c211d_0         1.9 MB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        19.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   nodejs             conda-forge/osx-64::nodejs-12.4.0-h6de7cb9_0
#   python_abi         conda-forge/osx-64::python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.12.5-h033912b_0
#   certifi               pkgs/main::certifi-2020.6.20-py37_0 --> conda-forge::certifi-2020.12.5-py37hf985489_0
#   openssl              pkgs/main::openssl-1.1.1g-h1de35cc_0 --> conda-forge::openssl-1.1.1i-h35c211d_0
#
#
#
# Downloading and Extracting Packages
# nodejs-12.4.0        | 16.8 MB   | ##################################### | 100%
# openssl-1.1.1i       | 1.9 MB    | ##################################### | 100%
# ca-certificates-2020 | 138 KB    | ##################################### | 100%
# python_abi-3.7       | 4 KB      | ##################################### | 100%
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from tensorflow.keras.models import load_model
from cv2 import cv2
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
path = Path()

# %%
deploy_model = load_model('./model.h5', compile = True)

# %%
 
#new_image = cv2.resize(np.float32('Tensorflow-CNN-Comparisons/three.jpg'),(1,28,28))
#deploy_model.predict('3.jpg')

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (7.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (4.3.3)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (7.15.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (5.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: six in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets) (1.15.0)
# Requirement already satisfied: decorator in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets) (4.4.2)
# Requirement already satisfied: ipython-genutils in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (3.0.5)
# Requirement already satisfied: pickleshare in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.17.1)
# Requirement already satisfied: setuptools>=18.5 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (47.3.1.post20200622)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.0)
# Requirement already satisfied: backcall in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied: pygments in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.6.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.0.3)
# Requirement already satisfied: jupyter-core in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: jupyter-client in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.3)
# Requirement already satisfied: tornado>=4.2 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: wcwidth in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.4)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.6.0)
# Requirement already satisfied: Send2Trash in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: nbconvert in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (5.6.1)
# Requirement already satisfied: pyzmq>=17 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (19.0.1)
# Requirement already satisfied: terminado>=0.8.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jinja2 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.2)
# Requirement already satisfied: prometheus-client in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.6.1)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: testpath in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: bleach in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.1.5)
# Requirement already satisfied: entrypoints>=0.2.2 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied: defusedxml in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.1.0)
# Requirement already satisfied: webencodings in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /anaconda3/envs/tensorflow/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
upload = FileUpload()

# %%
jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
#   File "<ipython-input-26-c2a3404c0366>", line 1
#     jupyter labextension install @jupyter-widgets/jupyterlab-manager
#                        ^
# SyntaxError: invalid syntax

# %%
import ipywidgets as widgets 
from IPython.display import display
from ipywidgets import FileUpload

# %%
upload = FileUpload()

# %%
upload
# Out:
# FileUpload(value={}, description='Upload')
