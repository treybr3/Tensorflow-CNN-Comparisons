# %%
from PIL import Image
import numpy as np

# %%
# data for .fit method 
def examples(x_data):
    pass

def results(y_data):
    pass

def split(x_data,y_data):
    x_train = x_data.#split into 80 percent of x_data
    y_train = y_data.#split into 80 percent of y_data
    x_test = y_data.#split into 20 percent of x_data
    


def np_data(image_path):
    data = [np.array((Image.open(i))) for i in image_path]
    return data 

# input shape for tensorflow 1st Conv layer
def input_shape(data):
    row = data[1]
    column = data[2]
    return [row,column]

# %%
import os 
# print all files & folders recursively
for dirpath, dirnames, filenames in os.walk("."):
    # iterate over directories
    print(type(dirpath))
    print(dirpath)
    for dirname in dirnames:
        print("Directory:", os.path.join(dirpath, dirname))
        print(type(dirnames))
    # iterate over files
    for filename in filenames:
        print("File:", os.path.join(dirpath, filename))
        print(type(filename))
# Out:
# <class 'str'>
# .
# Directory: ./.ipynb_checkpoints
# <class 'list'>
# Directory: ./.git
# <class 'list'>
# File: ./Handling Tensorflow Data .ipynb
# <class 'str'>
# File: ./CNN-Comparisons-Tensorflow-SGD.ipynb
# <class 'str'>
# File: ./Untitled.ipynb
# <class 'str'>
# File: ./CNN-Comparisons-Tensorflow-Adadelta.ipynb
# <class 'str'>
# File: ./CNN-Comparisons-Tensorflow-SGD-Bad-Architecture-Bad-Accuracy.ipynb
# <class 'str'>
# File: ./CNN-Comparisons-Adam.ipynb
# <class 'str'>
# File: ./README.md
# <class 'str'>
# <class 'str'>
# ./.ipynb_checkpoints
# File: ./.ipynb_checkpoints/CNN-Comparisons-Tensorflow-SGD-checkpoint.ipynb
# <class 'str'>
# File: ./.ipynb_checkpoints/CNN-Comparisons-Tensorflow-Adadelta-checkpoint.ipynb
# <class 'str'>
# File: ./.ipynb_checkpoints/Handling Tensorflow Data -checkpoint.ipynb
# <class 'str'>
# File: ./.ipynb_checkpoints/CNN-Comparisons-Tensorflow-SGD-Bad-Architecture-Bad-Accuracy-checkpoint.ipynb
# <class 'str'>
# ...
